# %%
x= 0
a= 0
d=0
h=0
n= 0
sm= 0
ap= 0
re= 0

values= int(input("\n Introduce the number of datas that you want to use: "))
v= values
x=[]

for i in range (0, values):
    c= float(input(f"\n introduce the data{i+1}: "))
    x.append(c)
    n += c

print("\n what operation the user wants to calculate: ")
print("\n 1 sample mean")
print("\n 2 mode")
print("\n 3 standard derivation")

option= int(input("\n choose a option:\n "))

if option == 1 :
        
    sm= n / v
    print("\n the sample mean is\n",sm)
    
if option == 2 :
    
    re = 0 
    for i in x:
            
        ap = x.count(i)                                                             
        if ap > re:
            re = ap                                                      
                                                                                         
mode = [] 

for i in x:
    
    ap = x.count(i)                                                             
    if ap == re and i not in mode:                                   
        mode.append(i) 
        print ("\n mode is: ", mode) 
       
if option == 3:
        for s in range(0, values):
            d+=((x[s]-sm)**2)
            h=d/v
            ds=h**.5
        print("The Standard Deviation is: ",ds)   

if option > 3:
    print("Error")
# Out:
#  Introduce the number of datas that you want to use: 8
#
#  introduce the data1: 4
#
#  introduce the data2: 4
#
#  introduce the data3: 4
#
#  introduce the data4: 5
#
#  introduce the data5: 3
#
#  introduce the data6: 1
#
#  introduce the data7: 6
#
#  introduce the data8: 8
#
#  what operation the user wants to calculate:
#
#  1 sample mean
#
#  2 mode
#
#  3 standard derivation
#
#  choose a option:
#  2
#
#  mode is:  [4.0]
